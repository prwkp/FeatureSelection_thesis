# %%
import pandas as pd
import numpy as np
import math
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost import XGBClassifier

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from datetime import datetime
from sklearn.metrics import classification_report, confusion_matrix


from sklearn.inspection import permutation_importance
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from skfeature.function.similarity_based import fisher_score
from sklearn.feature_selection import VarianceThreshold
from kydavra import MultiSURFSelector
from sklearn.feature_selection import RFE

import eli5
from eli5.sklearn import PermutationImportance
from eli5.permutation_importance import get_score_importances
from sklearn.feature_selection import SelectFromModel

from boruta import BorutaPy

import shap

import statistics

# create the random forest model.
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier


from sklearn.preprocessing import StandardScaler

# from sklearn.experimental import enable_halving_search_cv  # noqa
# from sklearn.model_selection import HalvingGridSearchCV
from boruta import BorutaPy
import random
from sklearn.feature_selection import mutual_info_classif as MIC
from functools import reduce

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
# for threshold
def filter_arr(sample_arr, filter_index):
    result_val = sample_arr[filter_index]
    result_index = filter_index
    compare_index = filter_index + 1
    if sample_arr[0] == sample_arr[filter_index]:
        return (0,0)
        
    if (len(sample_arr) -1 == filter_index):
        compare_index = filter_index - 1
    
    if (sample_arr[filter_index] == sample_arr[compare_index]):
        for index, val in enumerate(sample_arr):
            if (val == result_val):
                result_val = sample_arr[index - 1]
                result_index = index - 1

    return (result_val, result_index)

# %%
def categorise(row):  
    if row['Overall Probability'] >= 0.8 :
        return 1
    else:
        return 0

# %%
def crossvalidresults(model,X,y):
    rfc_cv_score = cross_val_score(model, X, y, cv=10)
    rfc_cv_f1 = cross_val_score(model, X, y, scoring="f1", cv = 10).mean()
    rfc_cv_f1sd = cross_val_score(model, X, y, scoring="f1", cv = 10).std()
    print("=== Mean F1 Score ===")
    print("Mean F1 Score - : ", rfc_cv_f1)
    print("=== sd F1 Score ===")
    print("sd F1 Score - : ", rfc_cv_f1sd)
    print('\n')

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('colon_.csv', header=0)

df = df.rename(columns={'NSP': 'class'})
df
# Out:
#        H55933     R39465    R39465_     R85482     U14973      R02593  \
# 0   8589.4160  5468.2407  4263.4077  4064.9358  1997.8930   5282.3250
# 1   9164.2540  6719.5293  4883.4487  3718.1590  2015.2214   5569.9070
# 2   3825.7050  6970.3613  5369.9688  4705.6500  1166.5536   1572.1678
# 3   6246.4487  7823.5340  5955.8350  3975.5642  2002.6132   2130.5430
# 4   3230.3286  3694.4500  3400.7400  3463.5857  2181.4202   2922.7820
# ..        ...        ...        ...        ...        ...         ...
# 57  4972.1660  4173.9180  3668.5337  1567.5554  1570.4406   3466.8108
# 58  9112.3720  6824.4863  5982.8460  3147.0430  4847.3080  11222.6820
# 59  6730.6250  3472.1250  2559.4624  2624.6892  1596.2179   4372.7890
# 0  -0.323301  0.895112 -0.746602 -0.422099 -0.187349  0.190130 -0.447078
# 1  -0.557342  0.669089 -0.509331 -0.103231 -1.107699  0.346171 -0.506699
# 2  -0.337205 -0.996201 -0.294266 -0.226291 -1.474261  0.924489 -0.559060
# 3  -0.842696  1.573117 -0.288112 -0.756473 -1.615868  0.778825 -0.583363
# 4  -0.508844 -1.129175 -0.512117 -0.305257 -0.741701 -0.840211 -0.781918
# ..       ...       ...       ...       ...       ...       ...       ...
# 57 -0.943842 -0.352548 -0.990425 -1.211775 -0.769288 -0.409793 -0.460243
# 58 -0.865433  0.055777 -0.486910 -0.831482  0.277997 -0.532567 -0.725131
# 59 -0.331691 -0.108514  0.588588  0.254999 -1.021492  0.561923 -0.027169
# 60 -0.394032 -0.696289  0.038639 -0.193423 -0.487557 -0.589991 -0.282262
# 61  0.306191 -0.545922 -0.062219 -0.472832  0.812326  0.715645  0.205484
#
#       M33210    H18490    H40891    R77780    T49647  class
# 0  -0.910785 -0.190557 -0.449632  0.793452 -0.506460      0
# 1  -0.624784  0.796365  0.820597 -0.230103 -0.929943      1
# 2   0.255224 -0.618751 -0.827886 -0.973982 -0.987372      0
# 3  -0.733993 -0.418553 -0.829446 -0.085678 -0.954397      1
# 4   0.247276 -0.128908 -0.656721 -1.199498 -0.395996      0
# ..       ...       ...       ...       ...       ...    ...
# 57 -0.559159 -0.619189 -0.661833 -1.029877 -1.151004      0
# 58 -0.253809 -0.878784 -0.092226 -0.787619 -0.383436      0
# 59 -0.377525  0.144432  0.212960  1.044458 -1.261602      1
# 60 -0.020142 -0.177631  0.037472 -0.539004 -0.699473      0
# 61  0.537765 -0.190163 -0.432020 -0.088823 -0.118393      1
#
# [62 rows x 2001 columns]

# %%
# df1['class'] = df1.apply(lambda row: categorise(row), axis=1)
print('class 0 = ',df1['class'].value_counts()[0],'ตัว')
print('class 1 = ',df1['class'].value_counts()[1],'ตัว')
print('Majority Class= ', df1['class'].value_counts()[0]/len(df1))
# Out:
# class 0 =  40 ตัว
# class 1 =  22 ตัว
# Majority Class=  0.6451612903225806

# %%
# threshold:

log_2base = math.log(len(df1),2.0)
base2n = int(round(log_2base,0))
p2_5 = int(round(len(df1.columns)*0.025,0))
p5 =  int(round(len(df1.columns)*0.05,0))
p10 =  int(round(len(df1.columns)*0.1,0))
p20 =  int(round(len(df1.columns)*0.2,0))

print('treshold logbase2(n):', base2n)
print('treshold 2.5%:',p2_5)
print('treshold 5%:',p5)
print('treshold 10%:',p10)
print('treshold 20%:',p20)

thres_d = {'base2n':base2n,
              'p2_5':p2_5,
              'p5':p5,
              'p10':p10,
              'p20':p20}


thres_d
# Out:
# treshold logbase2(n): 6
# treshold 2.5%: 50
# treshold 5%: 100
# treshold 10%: 200
# treshold 20%: 400
# {'base2n': 6, 'p2_5': 50, 'p5': 100, 'p10': 200, 'p20': 400}

# %%
X_ = df1.drop(['class'], axis=1)
len(X_.columns)
# Out:
# 2000

# %%
paramXGBoost_grid1 = {"subsample":[0.5, 0.75, 1],
              "colsample_bytree":[0.5, 0.75, 1],
              "max_depth":[5, 6, 7],
              "min_child_weight":[1,5,15],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid2 = {"subsample":[0.2,0.6,0.9],
              "colsample_bytree":[0.5, 0.75, 1],
              "max_depth":[7,15,25],
              "min_child_weight":[0.1,0.5,1],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid3 = {"subsample":[0.2,0.6,0.9],
              "colsample_bytree":[0.1,0.25, 0.5],
              "max_depth":[10,15,20],
              "min_child_weight":[20,40,60],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
paramXGBoost_grid4 = {"subsample":[0.75,0.9,1],
              "colsample_bytree":[0.1,0.25, 0.5],
              "max_depth":[5,10,15],
              "min_child_weight":[5,10,20],
              "learning_rate":[0.1, 0.01, 0.05],
              'eta': [0.01, 0.015, 0.02]
    }

# %%
param_d = {'set1':paramXGBoost_grid1,
           'set2':paramXGBoost_grid2,
           'set3':paramXGBoost_grid3,
           'set4':paramXGBoost_grid4
          }

param_d
# Out:
# {'set1': {'subsample': [0.5, 0.75, 1],
#   'colsample_bytree': [0.5, 0.75, 1],
#   'max_depth': [5, 6, 7],
#   'min_child_weight': [1, 5, 15],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set2': {'subsample': [0.2, 0.6, 0.9],
#   'colsample_bytree': [0.5, 0.75, 1],
#   'max_depth': [7, 15, 25],
#   'min_child_weight': [0.1, 0.5, 1],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set3': {'subsample': [0.2, 0.6, 0.9],
#   'colsample_bytree': [0.1, 0.25, 0.5],
#   'max_depth': [10, 15, 20],
#   'min_child_weight': [20, 40, 60],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]},
#  'set4': {'subsample': [0.75, 0.9, 1],
#   'colsample_bytree': [0.1, 0.25, 0.5],
#   'max_depth': [5, 10, 15],
#   'min_child_weight': [5, 10, 20],
#   'learning_rate': [0.1, 0.01, 0.05],
#   'eta': [0.01, 0.015, 0.02]}}

# %% [markdown]
# # XGBoost

# %%
# baseline model

X = df1.drop(['class'], axis=1)
y = df1['class']
 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123) 


xgbc = XGBClassifier(random_state=123)
xgbc.fit(X_train,y_train)

print('\n')

# #result
# crossvalidresults(model=rfc,X=X,y=y)

## results F1 and stdF1 ##
avgF1_baselineXGBoost = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1_baselineXGBoost = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1_baselineXGBoost)
print('std F1 Score: ', stdF1_baselineXGBoost)
# Out:
# Mean F1 Score:  0.6233333333333333
# std F1 Score:  0.2732723509207943

# %%
n_baselineXGBoost = len(X_.columns)
n_baselineXGBoost
# Out:
# 2000

# %%
# tuned baseline model_ parameterset1 

start_time = timer(None)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid1,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X_train, y_train)

timer(start_time)
print(grid_search.best_params_)


xgbc_tuned1 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned1.fit(X_train,y_train)

print('\n')

## results F1 and stdF1 ##
avgF1set1_baselineXGBoost = cross_val_score(xgbc_tuned1, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set1_baselineXGBoost = cross_val_score(xgbc_tuned1, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set1_baselineXGBoost)
print('std F1 Score: ', stdF1set1_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
#  Time taken: 0 hours 14 minutes and 32.15 seconds.
# {'colsample_bytree': 0.5, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.75}
#
#
# Mean F1 Score:  0.6923809523809524
# std F1 Score:  0.2964047609484793

# %%
# tuned baseline model_ parameterset2

start_time = timer(None)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid2,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X_train, y_train)

timer(start_time)
print(grid_search.best_params_)


xgbc_tuned2 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned2.fit(X_train,y_train)

print('\n')

## results F1 and stdF1 ##
avgF1set2_baselineXGBoost = cross_val_score(xgbc_tuned2, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set2_baselineXGBoost = cross_val_score(xgbc_tuned2, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set2_baselineXGBoost)
print('std F1 Score: ', stdF1set2_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
#  Time taken: 0 hours 17 minutes and 47.37 seconds.
# {'colsample_bytree': 0.5, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6}
#
#
# Mean F1 Score:  0.7223809523809523
# std F1 Score:  0.18550721056085134

# %%
# tuned baseline model_ parameterset3

start_time = timer(None)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid3,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X_train, y_train)

timer(start_time)
print(grid_search.best_params_)


xgbc_tuned3 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned3.fit(X_train,y_train)

print('\n')

## results F1 and stdF1 ##
avgF1set3_baselineXGBoost = cross_val_score(xgbc_tuned3, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set3_baselineXGBoost = cross_val_score(xgbc_tuned3, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set3_baselineXGBoost)
print('std F1 Score: ', stdF1set3_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
#  Time taken: 0 hours 12 minutes and 19.47 seconds.
# {'colsample_bytree': 0.1, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 20, 'subsample': 0.2}
#
#
# Mean F1 Score:  0.0
# std F1 Score:  0.0

# %%
# tuned baseline model_ parameterset4

start_time = timer(None)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgbc, param_grid = paramXGBoost_grid4,
                           cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
# Fit the grid search to the data
grid_search.fit(X_train, y_train)

timer(start_time)
print(grid_search.best_params_)


xgbc_tuned4 = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                   max_depth=grid_search.best_params_['max_depth'],
                                   colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                   min_child_weight=grid_search.best_params_['min_child_weight'],
                                   learning_rate=grid_search.best_params_['learning_rate'],
                                   eta=grid_search.best_params_['eta'])
xgbc_tuned4.fit(X_train,y_train)

## results F1 and stdF1 ##
avgF1set4_baselineXGBoost = cross_val_score(xgbc_tuned4, X, y, scoring="f1", cv = 10).mean() ##<3## 
stdF1set4_baselineXGBoost = cross_val_score(xgbc_tuned4, X, y, scoring="f1", cv = 10).std() ##<3##
print('Mean F1 Score: ', avgF1set4_baselineXGBoost)
print('std F1 Score: ', stdF1set4_baselineXGBoost)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
#  Time taken: 0 hours 11 minutes and 0.16 seconds.
# {'colsample_bytree': 0.1, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.75}
# Mean F1 Score:  0.4333333333333333
# std F1 Score:  0.29059326290271154

# %%
output_basedlineXGBoost = {'n_baselineXGBoost':n_baselineXGBoost ,
                   'avgF1_baselineXGBoost':avgF1_baselineXGBoost ,
                   'stdF1_baselineXGBoost': stdF1_baselineXGBoost,
                   'avgF1set1_baselineXGBoost':avgF1set1_baselineXGBoost  ,
                   'stdF1set1_baselineXGBoost': stdF1set1_baselineXGBoost,
                   'avgF1set2_baselineXGBoost':avgF1set2_baselineXGBoost ,
                   'stdF1set2_baselineXGBoost':stdF1set2_baselineXGBoost ,
                   'avgF1set3_baselineXGBoost':avgF1set3_baselineXGBoost ,
                   'stdF1set3_baselineXGBoost':stdF1set3_baselineXGBoost ,
                   'avgF1set4_baselineXGBoost':avgF1set4_baselineXGBoost ,
                   'stdF1set4_baselineXGBoost':stdF1set4_baselineXGBoost ,
                     }
output_basedlineXGBoost
# Out:
# {'n_baselineXGBoost': 2000,
#  'avgF1_baselineXGBoost': 0.6233333333333333,
#  'stdF1_baselineXGBoost': 0.2732723509207943,
#  'avgF1set1_baselineXGBoost': 0.6923809523809524,
#  'stdF1set1_baselineXGBoost': 0.2964047609484793,
#  'avgF1set2_baselineXGBoost': 0.7223809523809523,
#  'stdF1set2_baselineXGBoost': 0.18550721056085134,
#  'avgF1set3_baselineXGBoost': 0.0,
#  'stdF1set3_baselineXGBoost': 0.0,
#  'avgF1set4_baselineXGBoost': 0.4333333333333333,
#  'stdF1set4_baselineXGBoost': 0.29059326290271154}

# %%
output_basedlineXGBoost = pd.DataFrame([output_basedlineXGBoost])
output_basedlineXGBoost = output_basedlineXGBoost.transpose()
output_basedlineXGBoost.to_csv('output_basedlineXGBoost.csv', index=True)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# # Filter

# %%
# Mutual Information: Filter method
# Mutual Information: Filter method
start_time = timer(None)
mi_XGBoostscore = MIC(X_train,y_train)
mi_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_MI':mi_XGBoostscore})
mi_XGBoostfeatures['value_MI'] = mi_XGBoostfeatures['value_MI'].map('{:,.19f}'.format)
""" the more Mutual Information is the more feature importance it will have"""
mi_XGBoostfeatures = mi_XGBoostfeatures.sort_values(by='value_MI',ascending=False)
# mi_XGBoostfeatures = mi_XGBoostfeatures.set_index('Feature')
mi_XGBoostfeatures = mi_XGBoostfeatures.reset_index()
mi_XGBoostfeatures.to_csv('mi_XGBoostfeatures.csv', index=True)
timer(start_time)
mi_XGBoostfeatures
# Out:
#  Time taken: 0 hours 0 minutes and 4.0 seconds.
#       index  Feature               value_MI
# 0       512   M22382  0.3694007175992788383
# 1       624   X12671  0.3386396585969231321
# 2      1670   M26383  0.3060107265315921143
# 3      1292   H23544  0.2957035414261122153
# 4        74   X55715  0.2837018809550639897
# ...     ...      ...                    ...
# 1995    959   D50063  0.0000000000000000000
# 1996    956   M25160  0.0000000000000000000
# 1997    954   T61090  0.0000000000000000000
# 1998    953   D31767  0.0000000000000000000
# 1999   1000  M16029_  0.0000000000000000000
#
# [2000 rows x 3 columns]

# %%
# # anova: Filter method


# """f_classif: It uses the ANOVA (analysis of variance) method to calculate the F-value, 
# which measures the ratio of the between-class variance to the within-class variance 
# for each feature."""

# start_time = timer(None)

# def select_featuresanovaf(X_train, y_train, X_test):
#  # configure to select all features
#  fs = SelectKBest(score_func=f_classif, k='all')
#  # learn relationship from training data
#  fs.fit(X_train, y_train)
#  # transform train input data
#  X_train_fs = fs.transform(X_train)
#  # transform test input data
#  X_test_fs = fs.transform(X_test)
#  return X_train_fs, X_test_fs, fs

# X_train_fs, X_test_fs, fs = select_featuresanovaf(X_train, y_train, X_test)
# ## what are scores for the features
# # for i in range(len(fs.scores_)):
# #     print('Feature %d: %f' % (i, fs.scores_[i]))

# anova_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
#                             'value_anova':fs.scores_})
# anova_XGBoostfeatures['value_anova'] = anova_XGBoostfeatures['value_anova'].map('{:,.19f}'.format)

# """ The larger the ratio, the larger the F-value, and the more important 
# the feature is considered to be."""
# anova_XGBoostfeatures = anova_XGBoostfeatures.sort_values(by='value_anova',ascending=False)
# anova_XGBoostfeatures = anova_XGBoostfeatures.set_index('Feature')
# anova_XGBoostfeatures = anova_XGBoostfeatures.reset_index()
# anova_XGBoostfeatures.to_csv('anova_XGBoostfeatures.csv', index=True)
# timer(start_time)
# anova_XGBoostfeatures

# %%
# variance treshold: Filter method
"""Variance threshold is a simple method for feature selection that removes all features 
whose variance doesn't meet a certain threshold."""
start_time = timer(None)
threshold = 0.5
selector = VarianceThreshold(threshold)
selector = selector.fit(X_train)
variances = selector.variances_

variancethres_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_variancethres':variances})
# variancethres_XGBoostfeatures['value_variancethres'] = variancethres_XGBoostfeatures['value_variancethres'].map('{:,.19f}'.format)


"""The idea behind this method is that features 
with low variance don't contain much information and can be removed without affecting 
the performance of the model."""
variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.sort_values(by='value_variancethres',ascending=False)
# variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.set_index('Feature')
variancethres_XGBoostfeatures = variancethres_XGBoostfeatures.reset_index()
variancethres_XGBoostfeatures.to_csv('variancethres_XGBoostfeatures.csv', index=True)
timer(start_time)
variancethres_XGBoostfeatures
# Out:
#  Time taken: 0 hours 0 minutes and 0.05 seconds.
#       index    Feature  value_variancethres
# 0      1240     T64885             1.237031
# 1      1207     H72965             1.234650
# 2      1558     M28373             1.233904
# 3      1894     R99907             1.227323
# 4      1908     U10886             1.227049
# ...     ...        ...                  ...
# 1995   1481     T64012             0.330151
# 1996    259   control8             0.122158
# 1997    260   control9             0.122158
# 1998    261  control10             0.122158
# 1999    262  control11             0.122158
#
# [2000 rows x 3 columns]

# %%
X_train.shape
# Out:
# (49, 2000)

# %%
# # fisher score: Filter method
# start_time = timer(None)
# fisher_XGBoostscore = fisher_score.fisher_score(X_train,y_train)
# # fisher_XGBoostscore = fisher_XGBoostscore.astype(float)
# # fisher_XGBoostscore = fisher_XGBoostscore.astype(int)
# fisher_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
#                             'value_fisher':fisher_XGBoostscore})
# # fisher_XGBoostfeatures['value_fisher'] = fisher_XGBoostfeatures['value_fisher'].map('{:,.19f}'.format)

# """Fisher score is a method that can be used to evaluate the importance of features in 
# a classification problem. It calculates the ratio of the between-class variance to 
# the within-class variance for each feature. The larger the ratio, the larger the Fisher score, 
# and the more important the feature is considered to be. So in general, the more Fisher score is 
# the more feature importance it will have."""
# fisher_XGBoostfeatures = fisher_XGBoostfeatures.sort_values(by='value_fisher',ascending=False)
# fisher_XGBoostfeatures = fisher_XGBoostfeatures.set_index('Feature')
# fisher_XGBoostfeatures = fisher_XGBoostfeatures.reset_index()


# fisher_XGBoostfeatures.to_csv('fisher_XGBoostfeatures.csv', index=True)
# timer(start_time)
# fisher_XGBoostfeatures
# # fisher_XGBoostscore

# %%
# MultiSURF: Filter method

features = list(X_.columns)

msrf = MultiSURFSelector(n_features=len(df1.columns)-1)
selected_cols = msrf.select(df1,'class')

list_of_numbers = list(range(1, len(df1.columns)))

MultiSURF_XGBoostfeatures = pd.DataFrame({'Feature':selected_cols,
                            'value_MultiSURF':list_of_numbers})
# # MultiSURF_XGBoostfeatures['value_MultiSURF'] = MultiSURF_XGBoostfeatures['value_MultiSURF'].map('{:,.19f}'.format)
# เรียงจากเลขน้อยคือสำคัญสูงสุด
MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.sort_values(by='value_MultiSURF',ascending=True)
# MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.set_index('Feature')
MultiSURF_XGBoostfeatures = MultiSURF_XGBoostfeatures.reset_index()

MultiSURF_XGBoostfeatures.to_csv('MultiSURF_XGBoostfeatures.csv', index=True)
# timer(start_time)
MultiSURF_XGBoostfeatures
# Out:
#       index Feature  value_MultiSURF
# 0         0  T64885                1
# 1         1  H71150                2
# 2         2  R99907                3
# 3         3  H46994                4
# 4         4  L07648                5
# ...     ...     ...              ...
# 1995   1995  R42127             1996
# 1996   1996  M29277             1997
# 1997   1997  R80612             1998
# 1998   1998  T59162             1999
# 1999   1999  X03068             2000
#
# [2000 rows x 3 columns]

# %%
# # correlation coefficient: Filter method
# #Using Pearson Correlation
# cor = df1.corr()
# cor_XGBoostscore = abs(cor["class"])
# cor_XGBoostscore = cor_XGBoostscore[:-1]
# cor_XGBoostscore = pd.DataFrame(data= cor_XGBoostscore)
# cor_XGBoostscore = cor_XGBoostscore.rename(columns={'class':'value_cor'})
# cor_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
#                             'value_cor':cor_XGBoostscore['value_cor']})
# cor_XGBoostfeatures['value_cor'] = cor_XGBoostfeatures['value_cor'].map('{:,.19f}'.format)

# cor_XGBoostfeatures = cor_XGBoostfeatures.sort_values(by='value_cor',ascending=False)
# cor_XGBoostfeatures = cor_XGBoostfeatures.set_index('Feature')
# cor_XGBoostfeatures.to_csv('cor_XGBoostfeatures.csv', index=True)
# timer(start_time)
# cor_XGBoostfeatures

# %% [markdown]
# # Wrapper

# %%
# SHAP: Wrapper method

start_time = timer(None)

# Explain model predictions using shap library:
explainer = shap.TreeExplainer(xgbc_tuned2) #### changehere
shap_values = explainer.shap_values(X_train)
vals= np.abs(shap_values).mean(0)

SHAP_XGBoostfeatures= pd.DataFrame({'Feature':list(X_.columns),
                                 'value_SHAP':vals})
SHAP_XGBoostfeatures['value_SHAP'] = SHAP_XGBoostfeatures['value_SHAP'].map('{:,.19f}'.format)
SHAP_XGBoostfeatures = SHAP_XGBoostfeatures.sort_values(by=['value_SHAP'],ascending=False)
SHAP_XGBoostfeatures = SHAP_XGBoostfeatures.set_index('Feature')
SHAP_XGBoostfeatures.to_csv('SHAP_XGBoostfeatures.csv', index=True)

timer(start_time)
SHAP_XGBoostfeatures
# Out:
#  Time taken: 0 hours 0 minutes and 0.12 seconds.
#                     value_SHAP
# Feature
# H40095   0.3403580188751220703
# M63391   0.3188769221305847168
# H08393   0.2932315468788146973
# M26383   0.2829504311084747314
# R87126   0.2168045192956924438
# ...                        ...
# H89983   0.0000000000000000000
# H71150   0.0000000000000000000
# D25216   0.0000000000000000000
# U18934   0.0000000000000000000
# T49647   0.0000000000000000000
#
# [2000 rows x 1 columns]

# %%
# Recursive Feature Elimination(RFE): Wrapper method
start_time = timer(None)

"""In this example, the parameter "n_features_to_select" is set to 1, 
which means that only one feature will be selected at each iteration 
of RFE"""

rfe = RFE(estimator=xgbc_tuned2, n_features_to_select=1) #### changehere
rfe.fit(X_train, y_train)

rfe_XGBoostfeatures = pd.DataFrame({'Feature':list(X_.columns),
                            'value_rfe':rfe.ranking_})

# rfe_XGBoostfeatures['value_XGBooste'] = rfe_XGBoostfeatures['value_XGBooste'].astype(int)
# rfe_XGBoostfeatures['value_XGBooste'] = rfe_XGBoostfeatures['value_XGBooste'].map('{:,.19f}'.format)
"""The RFE assigns a ranking value to each feature, typically starting from 1 for 
the most important feature, and increasing for the less important features."""
rfe_XGBoostfeatures = rfe_XGBoostfeatures.sort_values(by=['value_rfe'],ascending=True)
rfe_XGBoostfeatures = rfe_XGBoostfeatures.set_index('Feature')

rfe_XGBoostfeatures.to_csv('rfe_XGBoostfeatures.csv', index=True)
timer(start_time)
rfe_XGBoostfeatures
# Out:
#  Time taken: 0 hours 39 minutes and 56.57 seconds.
#          value_rfe
# Feature
# M63391           1
# H08393           2
# H40095           3
# M26383           4
# J05032           5
# ...            ...
# U14973        1996
# R85482        1997
# R39465_       1998
# R39465        1999
# H55933        2000
#
# [2000 rows x 1 columns]

# %%
# Boruta: Wrapper method: Wrapper method




feat_selector = BorutaPy(xgbc_tuned2, n_estimators='auto', verbose=2, random_state=1) #### changehere
# feat_selector.fit(X_train, y_train)
feat_selector = feat_selector.fit(np.array(X_train), np.array(y_train)) 
features = X.columns
feature_importance = feat_selector.ranking_
# feature_importance
boruta_XGBoostfeatures = pd.DataFrame(list(zip(X_.columns, feature_importance[0:].tolist())), 
                                  columns=['Feature','value_boruta'])

# output the feature importance ranking: 1 is most importance >ascending=True
boruta_XGBoostfeatures = boruta_XGBoostfeatures.sort_values(by=['value_boruta'],ascending=True)
boruta_XGBoostfeatures = boruta_XGBoostfeatures.set_index('Feature')

boruta_XGBoostfeatures.to_csv('boruta_XGBoostfeatures.csv', index=True)
timer(start_time)
boruta_XGBoostfeatures
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	2000
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	19 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	20 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	21 / 100
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	1986
# Iteration: 	22 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	23 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	24 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	25 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	26 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	27 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	28 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	1987
# Iteration: 	29 / 100
# Confirmed: 	1
# Tentative: 	12
# Rejected: 	1987
# Iteration: 	30 / 100
# Confirmed: 	1
# Tentative: 	12
# Rejected: 	1987
# Iteration: 	31 / 100
# Confirmed: 	1
# Tentative: 	12
# Rejected: 	1987
# Iteration: 	32 / 100
# Confirmed: 	1
# Tentative: 	12
# Rejected: 	1987
# Iteration: 	33 / 100
# Confirmed: 	1
# Tentative: 	12
# Rejected: 	1987
# Iteration: 	34 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	35 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	36 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	37 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	38 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	39 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	40 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	41 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	42 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	43 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	44 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	45 / 100
# Confirmed: 	2
# Tentative: 	11
# Rejected: 	1987
# Iteration: 	46 / 100
# Confirmed: 	3
# Tentative: 	10
# Rejected: 	1987
# Iteration: 	47 / 100
# Confirmed: 	3
# Tentative: 	10
# Rejected: 	1987
# Iteration: 	48 / 100
# Confirmed: 	3
# Tentative: 	10
# Rejected: 	1987
# Iteration: 	49 / 100
# Confirmed: 	3
# Tentative: 	10
# Rejected: 	1987
# Iteration: 	50 / 100
# Confirmed: 	3
# Tentative: 	10
# Rejected: 	1987
# Iteration: 	51 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	52 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	53 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	54 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	55 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	56 / 100
# Confirmed: 	4
# Tentative: 	9
# Rejected: 	1987
# Iteration: 	57 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	58 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	59 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	60 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	61 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	62 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	63 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	64 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	65 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	66 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	67 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	68 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	69 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	70 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	71 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	72 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	73 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	74 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	75 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	76 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	77 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	78 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	79 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	80 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	81 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	82 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	83 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	84 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	85 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	86 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	87 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	88 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	89 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	90 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	91 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	92 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	93 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	94 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	95 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	96 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	97 / 100
# Confirmed: 	5
# Tentative: 	8
# Rejected: 	1987
# Iteration: 	98 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	1987
# Iteration: 	99 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	1987
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	6
# Tentative: 	3
# Rejected: 	1987
#
#  Time taken: 0 hours 43 minutes and 55.09 seconds.
#           value_boruta
# Feature
# M63391               1
# M76378__             1
# U30825               1
# T60155               1
# U09564               1
# ...                ...
# L11370            1055
# T71207            1055
# H30734            1055
# M27749            1055
# T49647            1055
#
# [2000 rows x 1 columns]

# %% [markdown]
# # single FS

# %% [markdown]
# # Filter

# %%
method_Filter = {'MI': mi_XGBoostfeatures,
          'variancethres': variancethres_XGBoostfeatures,
          'MultiSURF': MultiSURF_XGBoostfeatures
         }

# %%
output_filter = dict()
start_time = timer(None)

for tres,t in thres_d.items():
    for met,m in method_Filter.items():
        k =(filter_arr(m.filter(regex='value').squeeze(), t-1))   
        if k[1] != 0:
            n = k[1]+1 
            print("n"+"_single"+met+"_"+tres+"XGBoost",n)
            output_filter["n"+"_single"+met+"_"+tres+"XGBoost"] = n
            df_selected = m.iloc[:k[1]+1]
            df_filter = df1.filter(items=df_selected['Feature'])
            X = df_filter
            y = df1['class']
            
            ## before tuned ##
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123) 
            xgbc = XGBClassifier(random_state=123)
            xgbc.fit(X_train,y_train)
            ## results F1 and stdF1 ##
            m = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() 
            s = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() 
            print("avgF1"+"_single"+met+"_"+tres+"XGBoost" , m)
            print("stdF1"+"_single"+met+"_"+tres+"XGBoost",s)
            output_filter["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = m
            output_filter["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = s
            
            for parm, p in param_d.items():
                # Instantiate the grid search model
                grid_search = GridSearchCV(estimator = xgbc, param_grid = p,
                                        cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
                # Fit the grid search to the data
                grid_search.fit(X_train, y_train)
        #         print(grid_search.best_params_)
                xgbc_tuned = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                                max_depth=grid_search.best_params_['max_depth'],
                                                colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                                min_child_weight=grid_search.best_params_['min_child_weight'],
                                                learning_rate=grid_search.best_params_['learning_rate'],
                                                eta=grid_search.best_params_['eta'])
                xgbc_tuned.fit(X_train,y_train)

                ## results F1 and stdF1 ##
                m_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).mean() 
                s_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).std() 
                print("avgF1"+parm+"_single"+met+"_"+tres+"XGBoost" , m_tune)
                print("stdF1"+parm+"_single"+met+"_"+tres+"XGBoost",s_tune)
                output_filter["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = m_tune
                output_filter["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = s_tune

        else:
            output_filter["n"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_filter["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_filter["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            for parm, p in param_d.items():
                output_filter["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
                output_filter["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
         

        
        
timer(start_time)
# Out:
# n_singleMI_base2nXGBoost 6
# avgF1_singleMI_base2nXGBoost 0.5847619047619047
# stdF1_singleMI_base2nXGBoost 0.3284527045684386
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_base2nXGBoost 0.6523809523809524
# stdF1set1_singleMI_base2nXGBoost 0.37724385372073066
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_base2nXGBoost 0.6423809523809524
# stdF1set2_singleMI_base2nXGBoost 0.3824402492124581
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_base2nXGBoost 0.0
# stdF1set3_singleMI_base2nXGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_base2nXGBoost 0.1
# stdF1set4_singleMI_base2nXGBoost 0.30000000000000004
# n_singlevariancethres_base2nXGBoost 6
# avgF1_singlevariancethres_base2nXGBoost 0.5
# stdF1_singlevariancethres_base2nXGBoost 0.3651483716701107
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_base2nXGBoost 0.4833333333333334
# stdF1set1_singlevariancethres_base2nXGBoost 0.35253053453251076
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_base2nXGBoost 0.39
# stdF1set2_singlevariancethres_base2nXGBoost 0.2687625966040166
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_base2nXGBoost 0.0
# stdF1set3_singlevariancethres_base2nXGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_base2nXGBoost 0.0
# stdF1set4_singlevariancethres_base2nXGBoost 0.0
# n_singleMultiSURF_base2nXGBoost 6
# avgF1_singleMultiSURF_base2nXGBoost 0.22666666666666666
# stdF1_singleMultiSURF_base2nXGBoost 0.29844039047465853
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_base2nXGBoost 0.2
# stdF1set1_singleMultiSURF_base2nXGBoost 0.33166247903554
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_base2nXGBoost 0.19666666666666668
# stdF1set2_singleMultiSURF_base2nXGBoost 0.3078419507907697
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_base2nXGBoost 0.0
# stdF1set3_singleMultiSURF_base2nXGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_base2nXGBoost 0.0
# stdF1set4_singleMultiSURF_base2nXGBoost 0.0
# n_singleMI_p2_5XGBoost 50
# avgF1_singleMI_p2_5XGBoost 0.6923809523809524
# stdF1_singleMI_p2_5XGBoost 0.2964047609484793
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p2_5XGBoost 0.71
# stdF1set1_singleMI_p2_5XGBoost 0.28676354952004157
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p2_5XGBoost 0.7066666666666668
# stdF1set2_singleMI_p2_5XGBoost 0.30724582991474436
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p2_5XGBoost 0.0
# stdF1set3_singleMI_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p2_5XGBoost 0.26666666666666666
# stdF1set4_singleMI_p2_5XGBoost 0.3265986323710904
# n_singlevariancethres_p2_5XGBoost 50
# avgF1_singlevariancethres_p2_5XGBoost 0.62
# stdF1_singlevariancethres_p2_5XGBoost 0.2700617213403879
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p2_5XGBoost 0.6033333333333334
# stdF1set1_singlevariancethres_p2_5XGBoost 0.27180466842528256
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p2_5XGBoost 0.7390476190476191
# stdF1set2_singlevariancethres_p2_5XGBoost 0.17175630048813234
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p2_5XGBoost 0.0
# stdF1set3_singlevariancethres_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p2_5XGBoost 0.2
# stdF1set4_singlevariancethres_p2_5XGBoost 0.30550504633038933
# n_singleMultiSURF_p2_5XGBoost 50
# avgF1_singleMultiSURF_p2_5XGBoost 0.8033333333333333
# stdF1_singleMultiSURF_p2_5XGBoost 0.22032803826214323
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p2_5XGBoost 0.77
# stdF1set1_singleMultiSURF_p2_5XGBoost 0.21315096371664224
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p2_5XGBoost 0.79
# stdF1set2_singleMultiSURF_p2_5XGBoost 0.2241279396535232
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p2_5XGBoost 0.0
# stdF1set3_singleMultiSURF_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p2_5XGBoost 0.06666666666666667
# stdF1set4_singleMultiSURF_p2_5XGBoost 0.19999999999999998
# n_singleMI_p5XGBoost 100
# avgF1_singleMI_p5XGBoost 0.6733333333333333
# stdF1_singleMI_p5XGBoost 0.2912806969993797
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p5XGBoost 0.72
# stdF1set1_singleMI_p5XGBoost 0.3081125335544358
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p5XGBoost 0.6533333333333334
# stdF1set2_singleMI_p5XGBoost 0.27455013709298665
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p5XGBoost 0.0
# stdF1set3_singleMI_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p5XGBoost 0.43
# stdF1set4_singleMI_p5XGBoost 0.3707200201409863
# n_singlevariancethres_p5XGBoost 100
# avgF1_singlevariancethres_p5XGBoost 0.5733333333333334
# stdF1_singlevariancethres_p5XGBoost 0.2649108864840737
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p5XGBoost 0.6066666666666667
# stdF1set1_singlevariancethres_p5XGBoost 0.26407069760451146
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p5XGBoost 0.5766666666666667
# stdF1set2_singlevariancethres_p5XGBoost 0.12741009902410927
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p5XGBoost 0.0
# stdF1set3_singlevariancethres_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p5XGBoost 0.2
# stdF1set4_singlevariancethres_p5XGBoost 0.30550504633038933
# n_singleMultiSURF_p5XGBoost 100
# avgF1_singleMultiSURF_p5XGBoost 0.779047619047619
# stdF1_singleMultiSURF_p5XGBoost 0.2268106785409954
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p5XGBoost 0.7223809523809523
# stdF1set1_singleMultiSURF_p5XGBoost 0.18550721056085134
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p5XGBoost 0.7366666666666666
# stdF1set2_singleMultiSURF_p5XGBoost 0.20024984394500786
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p5XGBoost 0.0
# stdF1set3_singleMultiSURF_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p5XGBoost 0.13333333333333333
# stdF1set4_singleMultiSURF_p5XGBoost 0.26666666666666666
# n_singleMI_p10XGBoost 200
# avgF1_singleMI_p10XGBoost 0.6923809523809524
# stdF1_singleMI_p10XGBoost 0.2964047609484793
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p10XGBoost 0.7566666666666666
# stdF1set1_singleMI_p10XGBoost 0.21501937897160184
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p10XGBoost 0.739047619047619
# stdF1set2_singleMI_p10XGBoost 0.31010787385043337
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p10XGBoost 0.0
# stdF1set3_singleMI_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p10XGBoost 0.31666666666666665
# stdF1set4_singleMI_p10XGBoost 0.32015621187164245
# n_singlevariancethres_p10XGBoost 200
# avgF1_singlevariancethres_p10XGBoost 0.4866666666666667
# stdF1_singlevariancethres_p10XGBoost 0.28565713714171403
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p10XGBoost 0.5433333333333332
# stdF1set1_singlevariancethres_p10XGBoost 0.254318260802833
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p10XGBoost 0.5833333333333333
# stdF1set2_singlevariancethres_p10XGBoost 0.26002136664341857
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p10XGBoost 0.0
# stdF1set3_singlevariancethres_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p10XGBoost 0.2
# stdF1set4_singlevariancethres_p10XGBoost 0.30550504633038933
# n_singleMultiSURF_p10XGBoost 200
# avgF1_singleMultiSURF_p10XGBoost 0.7223809523809523
# stdF1_singleMultiSURF_p10XGBoost 0.3179301681764955
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p10XGBoost 0.7223809523809523
# stdF1set1_singleMultiSURF_p10XGBoost 0.18550721056085134
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p10XGBoost 0.689047619047619
# stdF1set2_singleMultiSURF_p10XGBoost 0.30425590434500727
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p10XGBoost 0.0
# stdF1set3_singleMultiSURF_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p10XGBoost 0.35
# stdF1set4_singleMultiSURF_p10XGBoost 0.36855573979159967
# n_singleMI_p20XGBoost 400
# avgF1_singleMI_p20XGBoost 0.7423809523809524
# stdF1_singleMI_p20XGBoost 0.20277496658816127
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMI_p20XGBoost 0.6900000000000001
# stdF1set1_singleMI_p20XGBoost 0.31342197327777344
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMI_p20XGBoost 0.6866666666666666
# stdF1set2_singleMI_p20XGBoost 0.29371187695880924
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMI_p20XGBoost 0.0
# stdF1set3_singleMI_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMI_p20XGBoost 0.29999999999999993
# stdF1set4_singleMI_p20XGBoost 0.30550504633038933
# n_singlevariancethres_p20XGBoost 400
# avgF1_singlevariancethres_p20XGBoost 0.6616666666666666
# stdF1_singlevariancethres_p20XGBoost 0.16194134740701646
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlevariancethres_p20XGBoost 0.7083333333333333
# stdF1set1_singlevariancethres_p20XGBoost 0.2212653007891959
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlevariancethres_p20XGBoost 0.52
# stdF1set2_singlevariancethres_p20XGBoost 0.27616420236277306
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlevariancethres_p20XGBoost 0.0
# stdF1set3_singlevariancethres_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlevariancethres_p20XGBoost 0.2
# stdF1set4_singlevariancethres_p20XGBoost 0.30550504633038933
# n_singleMultiSURF_p20XGBoost 400
# avgF1_singleMultiSURF_p20XGBoost 0.6547619047619048
# stdF1_singleMultiSURF_p20XGBoost 0.2758885870630667
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleMultiSURF_p20XGBoost 0.6890476190476191
# stdF1set1_singleMultiSURF_p20XGBoost 0.3042559043450072
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleMultiSURF_p20XGBoost 0.6557142857142857
# stdF1set2_singleMultiSURF_p20XGBoost 0.28607952845081286
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleMultiSURF_p20XGBoost 0.0
# stdF1set3_singleMultiSURF_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleMultiSURF_p20XGBoost 0.06666666666666667
# stdF1set4_singleMultiSURF_p20XGBoost 0.19999999999999998
#
#  Time taken: 2 hours 8 minutes and 45.52 seconds.

# %%
output_filter
# Out:
# {'n_singleMI_base2nXGBoost': 6,
#  'avgF1_singleMI_base2nXGBoost': 0.5847619047619047,
#  'stdF1_singleMI_base2nXGBoost': 0.3284527045684386,
#  'avgF1set1_singleMI_base2nXGBoost': 0.6523809523809524,
#  'stdF1set1_singleMI_base2nXGBoost': 0.37724385372073066,
#  'avgF1set2_singleMI_base2nXGBoost': 0.6423809523809524,
#  'stdF1set2_singleMI_base2nXGBoost': 0.3824402492124581,
#  'avgF1set3_singleMI_base2nXGBoost': 0.0,
#  'stdF1set3_singleMI_base2nXGBoost': 0.0,
#  'avgF1set4_singleMI_base2nXGBoost': 0.1,
#  'stdF1set4_singleMI_base2nXGBoost': 0.30000000000000004,
#  'n_singlevariancethres_base2nXGBoost': 6,
#  'avgF1_singlevariancethres_base2nXGBoost': 0.5,
#  'stdF1_singlevariancethres_base2nXGBoost': 0.3651483716701107,
#  'avgF1set1_singlevariancethres_base2nXGBoost': 0.4833333333333334,
#  'stdF1set1_singlevariancethres_base2nXGBoost': 0.35253053453251076,
#  'avgF1set2_singlevariancethres_base2nXGBoost': 0.39,
#  'stdF1set2_singlevariancethres_base2nXGBoost': 0.2687625966040166,
#  'avgF1set3_singlevariancethres_base2nXGBoost': 0.0,
#  'stdF1set3_singlevariancethres_base2nXGBoost': 0.0,
#  'avgF1set4_singlevariancethres_base2nXGBoost': 0.0,
#  'stdF1set4_singlevariancethres_base2nXGBoost': 0.0,
#  'n_singleMultiSURF_base2nXGBoost': 6,
#  'avgF1_singleMultiSURF_base2nXGBoost': 0.22666666666666666,
#  'stdF1_singleMultiSURF_base2nXGBoost': 0.29844039047465853,
#  'avgF1set1_singleMultiSURF_base2nXGBoost': 0.2,
#  'stdF1set1_singleMultiSURF_base2nXGBoost': 0.33166247903554,
#  'avgF1set2_singleMultiSURF_base2nXGBoost': 0.19666666666666668,
#  'stdF1set2_singleMultiSURF_base2nXGBoost': 0.3078419507907697,
#  'avgF1set3_singleMultiSURF_base2nXGBoost': 0.0,
#  'stdF1set3_singleMultiSURF_base2nXGBoost': 0.0,
#  'avgF1set4_singleMultiSURF_base2nXGBoost': 0.0,
#  'stdF1set4_singleMultiSURF_base2nXGBoost': 0.0,
#  'n_singleMI_p2_5XGBoost': 50,
#  'avgF1_singleMI_p2_5XGBoost': 0.6923809523809524,
#  'stdF1_singleMI_p2_5XGBoost': 0.2964047609484793,
#  'avgF1set1_singleMI_p2_5XGBoost': 0.71,
#  'stdF1set1_singleMI_p2_5XGBoost': 0.28676354952004157,
#  'avgF1set2_singleMI_p2_5XGBoost': 0.7066666666666668,
#  'stdF1set2_singleMI_p2_5XGBoost': 0.30724582991474436,
#  'avgF1set3_singleMI_p2_5XGBoost': 0.0,
#  'stdF1set3_singleMI_p2_5XGBoost': 0.0,
#  'avgF1set4_singleMI_p2_5XGBoost': 0.26666666666666666,
#  'stdF1set4_singleMI_p2_5XGBoost': 0.3265986323710904,
#  'n_singlevariancethres_p2_5XGBoost': 50,
#  'avgF1_singlevariancethres_p2_5XGBoost': 0.62,
#  'stdF1_singlevariancethres_p2_5XGBoost': 0.2700617213403879,
#  'avgF1set1_singlevariancethres_p2_5XGBoost': 0.6033333333333334,
#  'stdF1set1_singlevariancethres_p2_5XGBoost': 0.27180466842528256,
#  'avgF1set2_singlevariancethres_p2_5XGBoost': 0.7390476190476191,
#  'stdF1set2_singlevariancethres_p2_5XGBoost': 0.17175630048813234,
#  'avgF1set3_singlevariancethres_p2_5XGBoost': 0.0,
#  'stdF1set3_singlevariancethres_p2_5XGBoost': 0.0,
#  'avgF1set4_singlevariancethres_p2_5XGBoost': 0.2,
#  'stdF1set4_singlevariancethres_p2_5XGBoost': 0.30550504633038933,
#  'n_singleMultiSURF_p2_5XGBoost': 50,
#  'avgF1_singleMultiSURF_p2_5XGBoost': 0.8033333333333333,
#  'stdF1_singleMultiSURF_p2_5XGBoost': 0.22032803826214323,
#  'avgF1set1_singleMultiSURF_p2_5XGBoost': 0.77,
#  'stdF1set1_singleMultiSURF_p2_5XGBoost': 0.21315096371664224,
#  'avgF1set2_singleMultiSURF_p2_5XGBoost': 0.79,
#  'stdF1set2_singleMultiSURF_p2_5XGBoost': 0.2241279396535232,
#  'avgF1set3_singleMultiSURF_p2_5XGBoost': 0.0,
#  'stdF1set3_singleMultiSURF_p2_5XGBoost': 0.0,
#  'avgF1set4_singleMultiSURF_p2_5XGBoost': 0.06666666666666667,
#  'stdF1set4_singleMultiSURF_p2_5XGBoost': 0.19999999999999998,
#  'n_singleMI_p5XGBoost': 100,
#  'avgF1_singleMI_p5XGBoost': 0.6733333333333333,
#  'stdF1_singleMI_p5XGBoost': 0.2912806969993797,
#  'avgF1set1_singleMI_p5XGBoost': 0.72,
#  'stdF1set1_singleMI_p5XGBoost': 0.3081125335544358,
#  'avgF1set2_singleMI_p5XGBoost': 0.6533333333333334,
#  'stdF1set2_singleMI_p5XGBoost': 0.27455013709298665,
#  'avgF1set3_singleMI_p5XGBoost': 0.0,
#  'stdF1set3_singleMI_p5XGBoost': 0.0,
#  'avgF1set4_singleMI_p5XGBoost': 0.43,
#  'stdF1set4_singleMI_p5XGBoost': 0.3707200201409863,
#  'n_singlevariancethres_p5XGBoost': 100,
#  'avgF1_singlevariancethres_p5XGBoost': 0.5733333333333334,
#  'stdF1_singlevariancethres_p5XGBoost': 0.2649108864840737,
#  'avgF1set1_singlevariancethres_p5XGBoost': 0.6066666666666667,
#  'stdF1set1_singlevariancethres_p5XGBoost': 0.26407069760451146,
#  'avgF1set2_singlevariancethres_p5XGBoost': 0.5766666666666667,
#  'stdF1set2_singlevariancethres_p5XGBoost': 0.12741009902410927,
#  'avgF1set3_singlevariancethres_p5XGBoost': 0.0,
#  'stdF1set3_singlevariancethres_p5XGBoost': 0.0,
#  'avgF1set4_singlevariancethres_p5XGBoost': 0.2,
#  'stdF1set4_singlevariancethres_p5XGBoost': 0.30550504633038933,
#  'n_singleMultiSURF_p5XGBoost': 100,
#  'avgF1_singleMultiSURF_p5XGBoost': 0.779047619047619,
#  'stdF1_singleMultiSURF_p5XGBoost': 0.2268106785409954,
#  'avgF1set1_singleMultiSURF_p5XGBoost': 0.7223809523809523,
#  'stdF1set1_singleMultiSURF_p5XGBoost': 0.18550721056085134,
#  'avgF1set2_singleMultiSURF_p5XGBoost': 0.7366666666666666,
#  'stdF1set2_singleMultiSURF_p5XGBoost': 0.20024984394500786,
#  'avgF1set3_singleMultiSURF_p5XGBoost': 0.0,
#  'stdF1set3_singleMultiSURF_p5XGBoost': 0.0,
#  'avgF1set4_singleMultiSURF_p5XGBoost': 0.13333333333333333,
#  'stdF1set4_singleMultiSURF_p5XGBoost': 0.26666666666666666,
#  'n_singleMI_p10XGBoost': 200,
#  'avgF1_singleMI_p10XGBoost': 0.6923809523809524,
#  'stdF1_singleMI_p10XGBoost': 0.2964047609484793,
#  'avgF1set1_singleMI_p10XGBoost': 0.7566666666666666,
#  'stdF1set1_singleMI_p10XGBoost': 0.21501937897160184,
#  'avgF1set2_singleMI_p10XGBoost': 0.739047619047619,
#  'stdF1set2_singleMI_p10XGBoost': 0.31010787385043337,
#  'avgF1set3_singleMI_p10XGBoost': 0.0,
#  'stdF1set3_singleMI_p10XGBoost': 0.0,
#  'avgF1set4_singleMI_p10XGBoost': 0.31666666666666665,
#  'stdF1set4_singleMI_p10XGBoost': 0.32015621187164245,
#  'n_singlevariancethres_p10XGBoost': 200,
#  'avgF1_singlevariancethres_p10XGBoost': 0.4866666666666667,
#  'stdF1_singlevariancethres_p10XGBoost': 0.28565713714171403,
#  'avgF1set1_singlevariancethres_p10XGBoost': 0.5433333333333332,
#  'stdF1set1_singlevariancethres_p10XGBoost': 0.254318260802833,
#  'avgF1set2_singlevariancethres_p10XGBoost': 0.5833333333333333,
#  'stdF1set2_singlevariancethres_p10XGBoost': 0.26002136664341857,
#  'avgF1set3_singlevariancethres_p10XGBoost': 0.0,
#  'stdF1set3_singlevariancethres_p10XGBoost': 0.0,
#  'avgF1set4_singlevariancethres_p10XGBoost': 0.2,
#  'stdF1set4_singlevariancethres_p10XGBoost': 0.30550504633038933,
#  'n_singleMultiSURF_p10XGBoost': 200,
#  'avgF1_singleMultiSURF_p10XGBoost': 0.7223809523809523,
#  'stdF1_singleMultiSURF_p10XGBoost': 0.3179301681764955,
#  'avgF1set1_singleMultiSURF_p10XGBoost': 0.7223809523809523,
#  'stdF1set1_singleMultiSURF_p10XGBoost': 0.18550721056085134,
#  'avgF1set2_singleMultiSURF_p10XGBoost': 0.689047619047619,
#  'stdF1set2_singleMultiSURF_p10XGBoost': 0.30425590434500727,
#  'avgF1set3_singleMultiSURF_p10XGBoost': 0.0,
#  'stdF1set3_singleMultiSURF_p10XGBoost': 0.0,
#  'avgF1set4_singleMultiSURF_p10XGBoost': 0.35,
#  'stdF1set4_singleMultiSURF_p10XGBoost': 0.36855573979159967,
#  'n_singleMI_p20XGBoost': 400,
#  'avgF1_singleMI_p20XGBoost': 0.7423809523809524,
#  'stdF1_singleMI_p20XGBoost': 0.20277496658816127,
#  'avgF1set1_singleMI_p20XGBoost': 0.6900000000000001,
#  'stdF1set1_singleMI_p20XGBoost': 0.31342197327777344,
#  'avgF1set2_singleMI_p20XGBoost': 0.6866666666666666,
#  'stdF1set2_singleMI_p20XGBoost': 0.29371187695880924,
#  'avgF1set3_singleMI_p20XGBoost': 0.0,
#  'stdF1set3_singleMI_p20XGBoost': 0.0,
#  'avgF1set4_singleMI_p20XGBoost': 0.29999999999999993,
#  'stdF1set4_singleMI_p20XGBoost': 0.30550504633038933,
#  'n_singlevariancethres_p20XGBoost': 400,
#  'avgF1_singlevariancethres_p20XGBoost': 0.6616666666666666,
#  'stdF1_singlevariancethres_p20XGBoost': 0.16194134740701646,
#  'avgF1set1_singlevariancethres_p20XGBoost': 0.7083333333333333,
#  'stdF1set1_singlevariancethres_p20XGBoost': 0.2212653007891959,
#  'avgF1set2_singlevariancethres_p20XGBoost': 0.52,
#  'stdF1set2_singlevariancethres_p20XGBoost': 0.27616420236277306,
#  'avgF1set3_singlevariancethres_p20XGBoost': 0.0,
#  'stdF1set3_singlevariancethres_p20XGBoost': 0.0,
#  'avgF1set4_singlevariancethres_p20XGBoost': 0.2,
#  'stdF1set4_singlevariancethres_p20XGBoost': 0.30550504633038933,
#  'n_singleMultiSURF_p20XGBoost': 400,
#  'avgF1_singleMultiSURF_p20XGBoost': 0.6547619047619048,
#  'stdF1_singleMultiSURF_p20XGBoost': 0.2758885870630667,
#  'avgF1set1_singleMultiSURF_p20XGBoost': 0.6890476190476191,
#  'stdF1set1_singleMultiSURF_p20XGBoost': 0.3042559043450072,
#  'avgF1set2_singleMultiSURF_p20XGBoost': 0.6557142857142857,
#  'stdF1set2_singleMultiSURF_p20XGBoost': 0.28607952845081286,
#  'avgF1set3_singleMultiSURF_p20XGBoost': 0.0,
#  'stdF1set3_singleMultiSURF_p20XGBoost': 0.0,
#  'avgF1set4_singleMultiSURF_p20XGBoost': 0.06666666666666667,
#  'stdF1set4_singleMultiSURF_p20XGBoost': 0.19999999999999998}

# %%
output_single_Filter_XGBoost = pd.DataFrame([output_filter])
output_single_Filter_XGBoost = output_single_Filter_XGBoost.transpose()
output_single_Filter_XGBoost.to_csv('output_single_Filter_XGBoost.csv', index=True)

# %% [markdown]
# # Wrapper

# %%
SHAP_XGBoostfeatures = pd.read_csv('SHAP_XGBoostfeatures.csv')
rfe_XGBoostfeatures = pd.read_csv('rfe_XGBoostfeatures.csv')
boruta_XGBoostfeatures = pd.read_csv('boruta_XGBoostfeatures.csv')

# %%
method_Wrapper = {  'SHAP':SHAP_XGBoostfeatures,
                    'rfe': rfe_XGBoostfeatures,
                    'boruta': boruta_XGBoostfeatures
                }

# %%
output_wrapper = dict()
start_time = timer(None)

for tres,t in thres_d.items():
    for met,m in method_Wrapper.items():
        k =(filter_arr(m.filter(regex='value').squeeze(), t-1))   
        if k[1] != 0:
            n = k[1]+1 
            print("n"+"_single"+met+"_"+tres+"XGBoost",n)
            output_wrapper["n"+"_single"+met+"_"+tres+"XGBoost"] = n
            df_selected = m.iloc[:k[1]+1]
            df_filter = df1.filter(items=df_selected['Feature'])
            X = df_filter
            y = df1['class']
            
            ## before tuned ##
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123) 
            xgbc = XGBClassifier(random_state=123)
            xgbc.fit(X_train,y_train)
            ## results F1 and stdF1 ##
            m = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).mean() 
            s = cross_val_score(xgbc, X, y, scoring="f1", cv = 10).std() 
            print("avgF1"+"_single"+met+"_"+tres+"XGBoost" , m)
            print("stdF1"+"_single"+met+"_"+tres+"XGBoost",s)
            output_wrapper["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = m
            output_wrapper["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = s
            
            for parm, p in param_d.items():
                # Instantiate the grid search model
                grid_search = GridSearchCV(estimator = xgbc, param_grid = p,
                                        cv = 5, n_jobs = -1, verbose = 2,scoring='f1')
                # Fit the grid search to the data
                grid_search.fit(X_train, y_train)
        #         print(grid_search.best_params_)
                xgbc_tuned = XGBClassifier(subsample=grid_search.best_params_['subsample'],
                                                max_depth=grid_search.best_params_['max_depth'],
                                                colsample_bytree=grid_search.best_params_['colsample_bytree'],
                                                min_child_weight=grid_search.best_params_['min_child_weight'],
                                                learning_rate=grid_search.best_params_['learning_rate'],
                                                eta=grid_search.best_params_['eta'])
                xgbc_tuned.fit(X_train,y_train)

                ## results F1 and stdF1 ##
                m_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).mean() 
                s_tune  = cross_val_score(xgbc_tuned, X, y, scoring="f1", cv = 10).std() 
                print("avgF1"+parm+"_single"+met+"_"+tres+"XGBoost" , m_tune)
                print("stdF1"+parm+"_single"+met+"_"+tres+"XGBoost",s_tune)
                output_wrapper["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = m_tune
                output_wrapper["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = s_tune

        else:
            output_wrapper["n"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_wrapper["avgF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            output_wrapper["stdF1"+"_single"+met+"_"+tres+"XGBoost"] = k[1]
            for parm, p in param_d.items():
                output_wrapper["avgF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
                output_wrapper["stdF1"+parm+"_single"+met+"_"+tres+"XGBoost"] = k[1]
         

        
        
timer(start_time)
# Out:
# n_singleSHAP_base2nXGBoost 6
# avgF1_singleSHAP_base2nXGBoost 0.7757142857142858
# stdF1_singleSHAP_base2nXGBoost 0.33576291441116235
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_base2nXGBoost 0.8233333333333333
# stdF1set1_singleSHAP_base2nXGBoost 0.22805944644129764
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_base2nXGBoost 0.7757142857142857
# stdF1set2_singleSHAP_base2nXGBoost 0.21463939067005125
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_base2nXGBoost 0.0
# stdF1set3_singleSHAP_base2nXGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_base2nXGBoost 0.1833333333333333
# stdF1set4_singleSHAP_base2nXGBoost 0.2833333333333333
# n_singlerfe_base2nXGBoost 6
# avgF1_singlerfe_base2nXGBoost 0.6557142857142857
# stdF1_singlerfe_base2nXGBoost 0.28607952845081286
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_base2nXGBoost 0.6890476190476191
# stdF1set1_singlerfe_base2nXGBoost 0.3042559043450072
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_base2nXGBoost 0.699047619047619
# stdF1set2_singlerfe_base2nXGBoost 0.2961261605259586
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_base2nXGBoost 0.0
# stdF1set3_singlerfe_base2nXGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_base2nXGBoost 0.39999999999999997
# stdF1set4_singlerfe_base2nXGBoost 0.41633319989322654
# n_singleSHAP_p2_5XGBoost 50
# avgF1_singleSHAP_p2_5XGBoost 0.6566666666666666
# stdF1_singleSHAP_p2_5XGBoost 0.2959166549328825
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p2_5XGBoost 0.8033333333333333
# stdF1set1_singleSHAP_p2_5XGBoost 0.2203280382621432
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p2_5XGBoost 0.8033333333333333
# stdF1set2_singleSHAP_p2_5XGBoost 0.22032803826214323
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p2_5XGBoost 0.0
# stdF1set3_singleSHAP_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p2_5XGBoost 0.14666666666666667
# stdF1set4_singleSHAP_p2_5XGBoost 0.29484459183327977
# n_singlerfe_p2_5XGBoost 50
# avgF1_singlerfe_p2_5XGBoost 0.6090476190476191
# stdF1_singlerfe_p2_5XGBoost 0.36389459239787725
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p2_5XGBoost 0.7733333333333333
# stdF1set1_singlerfe_p2_5XGBoost 0.23842072989663554
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p2_5XGBoost 0.7066666666666667
# stdF1set2_singlerfe_p2_5XGBoost 0.4013311184877976
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p2_5XGBoost 0.0
# stdF1set3_singlerfe_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p2_5XGBoost 0.05
# stdF1set4_singlerfe_p2_5XGBoost 0.15000000000000002
# n_singleboruta_p2_5XGBoost 38
# avgF1_singleboruta_p2_5XGBoost 0.6257142857142857
# stdF1_singleboruta_p2_5XGBoost 0.2851041103553167
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p2_5XGBoost 0.7733333333333333
# stdF1set1_singleboruta_p2_5XGBoost 0.20044395171163878
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p2_5XGBoost 0.8400000000000001
# stdF1set2_singleboruta_p2_5XGBoost 0.20912516188477495
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p2_5XGBoost 0.0
# stdF1set3_singleboruta_p2_5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p2_5XGBoost 0.27999999999999997
# stdF1set4_singleboruta_p2_5XGBoost 0.3448671241700683
# n_singleSHAP_p5XGBoost 79
# avgF1_singleSHAP_p5XGBoost 0.7423809523809524
# stdF1_singleSHAP_p5XGBoost 0.2027749665881613
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p5XGBoost 0.7633333333333333
# stdF1set1_singleSHAP_p5XGBoost 0.30856297754447326
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p5XGBoost 0.8200000000000001
# stdF1set2_singleSHAP_p5XGBoost 0.20231987873991358
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p5XGBoost 0.0
# stdF1set3_singleSHAP_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p5XGBoost 0.2833333333333333
# stdF1set4_singleSHAP_p5XGBoost 0.3655285366576884
# n_singlerfe_p5XGBoost 100
# avgF1_singlerfe_p5XGBoost 0.7233333333333334
# stdF1_singlerfe_p5XGBoost 0.32661564227357176
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p5XGBoost 0.709047619047619
# stdF1set1_singlerfe_p5XGBoost 0.3171904011266631
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p5XGBoost 0.62
# stdF1set2_singlerfe_p5XGBoost 0.35907288025320616
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p5XGBoost 0.0
# stdF1set3_singlerfe_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p5XGBoost 0.27999999999999997
# stdF1set4_singlerfe_p5XGBoost 0.3448671241700683
# n_singleboruta_p5XGBoost 38
# avgF1_singleboruta_p5XGBoost 0.6257142857142857
# stdF1_singleboruta_p5XGBoost 0.2851041103553167
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p5XGBoost 0.7733333333333333
# stdF1set1_singleboruta_p5XGBoost 0.20044395171163878
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p5XGBoost 0.8400000000000001
# stdF1set2_singleboruta_p5XGBoost 0.20912516188477495
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p5XGBoost 0.0
# stdF1set3_singleboruta_p5XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p5XGBoost 0.27999999999999997
# stdF1set4_singleboruta_p5XGBoost 0.3448671241700683
# n_singleSHAP_p10XGBoost 79
# avgF1_singleSHAP_p10XGBoost 0.7423809523809524
# stdF1_singleSHAP_p10XGBoost 0.2027749665881613
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p10XGBoost 0.7633333333333333
# stdF1set1_singleSHAP_p10XGBoost 0.30856297754447326
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p10XGBoost 0.8200000000000001
# stdF1set2_singleSHAP_p10XGBoost 0.20231987873991358
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p10XGBoost 0.0
# stdF1set3_singleSHAP_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p10XGBoost 0.2833333333333333
# stdF1set4_singleSHAP_p10XGBoost 0.3655285366576884
# n_singlerfe_p10XGBoost 200
# avgF1_singlerfe_p10XGBoost 0.6090476190476191
# stdF1_singlerfe_p10XGBoost 0.36389459239787725
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p10XGBoost 0.6090476190476191
# stdF1set1_singlerfe_p10XGBoost 0.36389459239787725
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p10XGBoost 0.709047619047619
# stdF1set2_singlerfe_p10XGBoost 0.3171904011266631
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p10XGBoost 0.0
# stdF1set3_singlerfe_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p10XGBoost 0.41666666666666663
# stdF1set4_singlerfe_p10XGBoost 0.28136571693556883
# n_singleboruta_p10XGBoost 125
# avgF1_singleboruta_p10XGBoost 0.6757142857142857
# stdF1_singleboruta_p10XGBoost 0.30201477641014196
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p10XGBoost 0.7057142857142857
# stdF1set1_singleboruta_p10XGBoost 0.2979430617202067
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p10XGBoost 0.7533333333333333
# stdF1set2_singleboruta_p10XGBoost 0.1863091814997616
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p10XGBoost 0.0
# stdF1set3_singleboruta_p10XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p10XGBoost 0.2333333333333333
# stdF1set4_singleboruta_p10XGBoost 0.2905932629027116
# n_singleSHAP_p20XGBoost 79
# avgF1_singleSHAP_p20XGBoost 0.7423809523809524
# stdF1_singleSHAP_p20XGBoost 0.2027749665881613
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleSHAP_p20XGBoost 0.7633333333333333
# stdF1set1_singleSHAP_p20XGBoost 0.30856297754447326
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleSHAP_p20XGBoost 0.8200000000000001
# stdF1set2_singleSHAP_p20XGBoost 0.20231987873991358
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleSHAP_p20XGBoost 0.0
# stdF1set3_singleSHAP_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleSHAP_p20XGBoost 0.2833333333333333
# stdF1set4_singleSHAP_p20XGBoost 0.3655285366576884
# n_singlerfe_p20XGBoost 400
# avgF1_singlerfe_p20XGBoost 0.589047619047619
# stdF1_singlerfe_p20XGBoost 0.34695990998719434
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singlerfe_p20XGBoost 0.7257142857142858
# stdF1set1_singlerfe_p20XGBoost 0.2148057182633634
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singlerfe_p20XGBoost 0.7233333333333334
# stdF1set2_singlerfe_p20XGBoost 0.2000277758490333
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singlerfe_p20XGBoost 0.0
# stdF1set3_singlerfe_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singlerfe_p20XGBoost 0.25
# stdF1set4_singlerfe_p20XGBoost 0.3095695936834451
# n_singleboruta_p20XGBoost 125
# avgF1_singleboruta_p20XGBoost 0.6757142857142857
# stdF1_singleboruta_p20XGBoost 0.30201477641014196
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set1_singleboruta_p20XGBoost 0.7057142857142857
# stdF1set1_singleboruta_p20XGBoost 0.2979430617202067
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set2_singleboruta_p20XGBoost 0.7533333333333333
# stdF1set2_singleboruta_p20XGBoost 0.1863091814997616
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set3_singleboruta_p20XGBoost 0.0
# stdF1set3_singleboruta_p20XGBoost 0.0
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# avgF1set4_singleboruta_p20XGBoost 0.2333333333333333
# stdF1set4_singleboruta_p20XGBoost 0.2905932629027116
#
#  Time taken: 1 hours 50 minutes and 50.74 seconds.

# %%
output_wrapper
# Out:
# {'n_singleSHAP_base2nXGBoost': 6,
#  'avgF1_singleSHAP_base2nXGBoost': 0.7757142857142858,
#  'stdF1_singleSHAP_base2nXGBoost': 0.33576291441116235,
#  'avgF1set1_singleSHAP_base2nXGBoost': 0.8233333333333333,
#  'stdF1set1_singleSHAP_base2nXGBoost': 0.22805944644129764,
#  'avgF1set2_singleSHAP_base2nXGBoost': 0.7757142857142857,
#  'stdF1set2_singleSHAP_base2nXGBoost': 0.21463939067005125,
#  'avgF1set3_singleSHAP_base2nXGBoost': 0.0,
#  'stdF1set3_singleSHAP_base2nXGBoost': 0.0,
#  'avgF1set4_singleSHAP_base2nXGBoost': 0.1833333333333333,
#  'stdF1set4_singleSHAP_base2nXGBoost': 0.2833333333333333,
#  'n_singlerfe_base2nXGBoost': 6,
#  'avgF1_singlerfe_base2nXGBoost': 0.6557142857142857,
#  'stdF1_singlerfe_base2nXGBoost': 0.28607952845081286,
#  'avgF1set1_singlerfe_base2nXGBoost': 0.6890476190476191,
#  'stdF1set1_singlerfe_base2nXGBoost': 0.3042559043450072,
#  'avgF1set2_singlerfe_base2nXGBoost': 0.699047619047619,
#  'stdF1set2_singlerfe_base2nXGBoost': 0.2961261605259586,
#  'avgF1set3_singlerfe_base2nXGBoost': 0.0,
#  'stdF1set3_singlerfe_base2nXGBoost': 0.0,
#  'avgF1set4_singlerfe_base2nXGBoost': 0.39999999999999997,
#  'stdF1set4_singlerfe_base2nXGBoost': 0.41633319989322654,
#  'n_singleboruta_base2nXGBoost': 0,
#  'avgF1_singleboruta_base2nXGBoost': 0,
#  'stdF1_singleboruta_base2nXGBoost': 0,
#  'avgF1set1_singleboruta_base2nXGBoost': 0,
#  'stdF1set1_singleboruta_base2nXGBoost': 0,
#  'avgF1set2_singleboruta_base2nXGBoost': 0,
#  'stdF1set2_singleboruta_base2nXGBoost': 0,
#  'avgF1set3_singleboruta_base2nXGBoost': 0,
#  'stdF1set3_singleboruta_base2nXGBoost': 0,
#  'avgF1set4_singleboruta_base2nXGBoost': 0,
#  'stdF1set4_singleboruta_base2nXGBoost': 0,
#  'n_singleSHAP_p2_5XGBoost': 50,
#  'avgF1_singleSHAP_p2_5XGBoost': 0.6566666666666666,
#  'stdF1_singleSHAP_p2_5XGBoost': 0.2959166549328825,
#  'avgF1set1_singleSHAP_p2_5XGBoost': 0.8033333333333333,
#  'stdF1set1_singleSHAP_p2_5XGBoost': 0.2203280382621432,
#  'avgF1set2_singleSHAP_p2_5XGBoost': 0.8033333333333333,
#  'stdF1set2_singleSHAP_p2_5XGBoost': 0.22032803826214323,
#  'avgF1set3_singleSHAP_p2_5XGBoost': 0.0,
#  'stdF1set3_singleSHAP_p2_5XGBoost': 0.0,
#  'avgF1set4_singleSHAP_p2_5XGBoost': 0.14666666666666667,
#  'stdF1set4_singleSHAP_p2_5XGBoost': 0.29484459183327977,
#  'n_singlerfe_p2_5XGBoost': 50,
#  'avgF1_singlerfe_p2_5XGBoost': 0.6090476190476191,
#  'stdF1_singlerfe_p2_5XGBoost': 0.36389459239787725,
#  'avgF1set1_singlerfe_p2_5XGBoost': 0.7733333333333333,
#  'stdF1set1_singlerfe_p2_5XGBoost': 0.23842072989663554,
#  'avgF1set2_singlerfe_p2_5XGBoost': 0.7066666666666667,
#  'stdF1set2_singlerfe_p2_5XGBoost': 0.4013311184877976,
#  'avgF1set3_singlerfe_p2_5XGBoost': 0.0,
#  'stdF1set3_singlerfe_p2_5XGBoost': 0.0,
#  'avgF1set4_singlerfe_p2_5XGBoost': 0.05,
#  'stdF1set4_singlerfe_p2_5XGBoost': 0.15000000000000002,
#  'n_singleboruta_p2_5XGBoost': 38,
#  'avgF1_singleboruta_p2_5XGBoost': 0.6257142857142857,
#  'stdF1_singleboruta_p2_5XGBoost': 0.2851041103553167,
#  'avgF1set1_singleboruta_p2_5XGBoost': 0.7733333333333333,
#  'stdF1set1_singleboruta_p2_5XGBoost': 0.20044395171163878,
#  'avgF1set2_singleboruta_p2_5XGBoost': 0.8400000000000001,
#  'stdF1set2_singleboruta_p2_5XGBoost': 0.20912516188477495,
#  'avgF1set3_singleboruta_p2_5XGBoost': 0.0,
#  'stdF1set3_singleboruta_p2_5XGBoost': 0.0,
#  'avgF1set4_singleboruta_p2_5XGBoost': 0.27999999999999997,
#  'stdF1set4_singleboruta_p2_5XGBoost': 0.3448671241700683,
#  'n_singleSHAP_p5XGBoost': 79,
#  'avgF1_singleSHAP_p5XGBoost': 0.7423809523809524,
#  'stdF1_singleSHAP_p5XGBoost': 0.2027749665881613,
#  'avgF1set1_singleSHAP_p5XGBoost': 0.7633333333333333,
#  'stdF1set1_singleSHAP_p5XGBoost': 0.30856297754447326,
#  'avgF1set2_singleSHAP_p5XGBoost': 0.8200000000000001,
#  'stdF1set2_singleSHAP_p5XGBoost': 0.20231987873991358,
#  'avgF1set3_singleSHAP_p5XGBoost': 0.0,
#  'stdF1set3_singleSHAP_p5XGBoost': 0.0,
#  'avgF1set4_singleSHAP_p5XGBoost': 0.2833333333333333,
#  'stdF1set4_singleSHAP_p5XGBoost': 0.3655285366576884,
#  'n_singlerfe_p5XGBoost': 100,
#  'avgF1_singlerfe_p5XGBoost': 0.7233333333333334,
#  'stdF1_singlerfe_p5XGBoost': 0.32661564227357176,
#  'avgF1set1_singlerfe_p5XGBoost': 0.709047619047619,
#  'stdF1set1_singlerfe_p5XGBoost': 0.3171904011266631,
#  'avgF1set2_singlerfe_p5XGBoost': 0.62,
#  'stdF1set2_singlerfe_p5XGBoost': 0.35907288025320616,
#  'avgF1set3_singlerfe_p5XGBoost': 0.0,
#  'stdF1set3_singlerfe_p5XGBoost': 0.0,
#  'avgF1set4_singlerfe_p5XGBoost': 0.27999999999999997,
#  'stdF1set4_singlerfe_p5XGBoost': 0.3448671241700683,
#  'n_singleboruta_p5XGBoost': 38,
#  'avgF1_singleboruta_p5XGBoost': 0.6257142857142857,
#  'stdF1_singleboruta_p5XGBoost': 0.2851041103553167,
#  'avgF1set1_singleboruta_p5XGBoost': 0.7733333333333333,
#  'stdF1set1_singleboruta_p5XGBoost': 0.20044395171163878,
#  'avgF1set2_singleboruta_p5XGBoost': 0.8400000000000001,
#  'stdF1set2_singleboruta_p5XGBoost': 0.20912516188477495,
#  'avgF1set3_singleboruta_p5XGBoost': 0.0,
#  'stdF1set3_singleboruta_p5XGBoost': 0.0,
#  'avgF1set4_singleboruta_p5XGBoost': 0.27999999999999997,
#  'stdF1set4_singleboruta_p5XGBoost': 0.3448671241700683,
#  'n_singleSHAP_p10XGBoost': 79,
#  'avgF1_singleSHAP_p10XGBoost': 0.7423809523809524,
#  'stdF1_singleSHAP_p10XGBoost': 0.2027749665881613,
#  'avgF1set1_singleSHAP_p10XGBoost': 0.7633333333333333,
#  'stdF1set1_singleSHAP_p10XGBoost': 0.30856297754447326,
#  'avgF1set2_singleSHAP_p10XGBoost': 0.8200000000000001,
#  'stdF1set2_singleSHAP_p10XGBoost': 0.20231987873991358,
#  'avgF1set3_singleSHAP_p10XGBoost': 0.0,
#  'stdF1set3_singleSHAP_p10XGBoost': 0.0,
#  'avgF1set4_singleSHAP_p10XGBoost': 0.2833333333333333,
#  'stdF1set4_singleSHAP_p10XGBoost': 0.3655285366576884,
#  'n_singlerfe_p10XGBoost': 200,
#  'avgF1_singlerfe_p10XGBoost': 0.6090476190476191,
#  'stdF1_singlerfe_p10XGBoost': 0.36389459239787725,
#  'avgF1set1_singlerfe_p10XGBoost': 0.6090476190476191,
#  'stdF1set1_singlerfe_p10XGBoost': 0.36389459239787725,
#  'avgF1set2_singlerfe_p10XGBoost': 0.709047619047619,
#  'stdF1set2_singlerfe_p10XGBoost': 0.3171904011266631,
#  'avgF1set3_singlerfe_p10XGBoost': 0.0,
#  'stdF1set3_singlerfe_p10XGBoost': 0.0,
#  'avgF1set4_singlerfe_p10XGBoost': 0.41666666666666663,
#  'stdF1set4_singlerfe_p10XGBoost': 0.28136571693556883,
#  'n_singleboruta_p10XGBoost': 125,
#  'avgF1_singleboruta_p10XGBoost': 0.6757142857142857,
#  'stdF1_singleboruta_p10XGBoost': 0.30201477641014196,
#  'avgF1set1_singleboruta_p10XGBoost': 0.7057142857142857,
#  'stdF1set1_singleboruta_p10XGBoost': 0.2979430617202067,
#  'avgF1set2_singleboruta_p10XGBoost': 0.7533333333333333,
#  'stdF1set2_singleboruta_p10XGBoost': 0.1863091814997616,
#  'avgF1set3_singleboruta_p10XGBoost': 0.0,
#  'stdF1set3_singleboruta_p10XGBoost': 0.0,
#  'avgF1set4_singleboruta_p10XGBoost': 0.2333333333333333,
#  'stdF1set4_singleboruta_p10XGBoost': 0.2905932629027116,
#  'n_singleSHAP_p20XGBoost': 79,
#  'avgF1_singleSHAP_p20XGBoost': 0.7423809523809524,
#  'stdF1_singleSHAP_p20XGBoost': 0.2027749665881613,
#  'avgF1set1_singleSHAP_p20XGBoost': 0.7633333333333333,
#  'stdF1set1_singleSHAP_p20XGBoost': 0.30856297754447326,
#  'avgF1set2_singleSHAP_p20XGBoost': 0.8200000000000001,
#  'stdF1set2_singleSHAP_p20XGBoost': 0.20231987873991358,
#  'avgF1set3_singleSHAP_p20XGBoost': 0.0,
#  'stdF1set3_singleSHAP_p20XGBoost': 0.0,
#  'avgF1set4_singleSHAP_p20XGBoost': 0.2833333333333333,
#  'stdF1set4_singleSHAP_p20XGBoost': 0.3655285366576884,
#  'n_singlerfe_p20XGBoost': 400,
#  'avgF1_singlerfe_p20XGBoost': 0.589047619047619,
#  'stdF1_singlerfe_p20XGBoost': 0.34695990998719434,
#  'avgF1set1_singlerfe_p20XGBoost': 0.7257142857142858,
#  'stdF1set1_singlerfe_p20XGBoost': 0.2148057182633634,
#  'avgF1set2_singlerfe_p20XGBoost': 0.7233333333333334,
#  'stdF1set2_singlerfe_p20XGBoost': 0.2000277758490333,
#  'avgF1set3_singlerfe_p20XGBoost': 0.0,
#  'stdF1set3_singlerfe_p20XGBoost': 0.0,
#  'avgF1set4_singlerfe_p20XGBoost': 0.25,
#  'stdF1set4_singlerfe_p20XGBoost': 0.3095695936834451,
#  'n_singleboruta_p20XGBoost': 125,
#  'avgF1_singleboruta_p20XGBoost': 0.6757142857142857,
#  'stdF1_singleboruta_p20XGBoost': 0.30201477641014196,
#  'avgF1set1_singleboruta_p20XGBoost': 0.7057142857142857,
#  'stdF1set1_singleboruta_p20XGBoost': 0.2979430617202067,
#  'avgF1set2_singleboruta_p20XGBoost': 0.7533333333333333,
#  'stdF1set2_singleboruta_p20XGBoost': 0.1863091814997616,
#  'avgF1set3_singleboruta_p20XGBoost': 0.0,
#  'stdF1set3_singleboruta_p20XGBoost': 0.0,
#  'avgF1set4_singleboruta_p20XGBoost': 0.2333333333333333,
#  'stdF1set4_singleboruta_p20XGBoost': 0.2905932629027116}

# %%
output_single_wrapper_XGBoost = pd.DataFrame([output_wrapper])
output_single_wrapper_XGBoost = output_single_wrapper_XGBoost.transpose()
output_single_wrapper_XGBoost.to_csv('output_single_wrapper_XGBoost.csv', index=True)
